# %% [markdown]
# ### Usage example

# %% [markdown]
# First, need to instantiate the image classifier.

# %%
from image_classification import ImageClassifier

ic = ImageClassifier(model_path="saved_models/EfficientNetV2S_100epochs_0p8dropout_best_val_loss.h5",
                     class_names=['Battery', 'Camera', 'Keyboard', 'Laptop', 'Microwave', 'Mobile', 'Mouse', 'PCB', 'Player', 'Printer', 'Smartwatch', 'Television', 'Washing Machine'])

# %% [markdown]
# Then proceed. Example usage:

# %%
pred, confidence = ic.predict_class('test_img_examples/galaxy_z_fold_7.webp')
print(pred, confidence)
# Out:
# Laptop 0.67375064

# %% [markdown]
# NB: first prediction will be slow, subsequent predictions much quicker

# %%
pred, confidence = ic.predict_class('test_img_examples/bat1.jpg')
print(pred, confidence)
# Out:
# Battery 0.9916647

# %%
pred, confidence = ic.predict_class('test_img_examples/bat2.jpg')
print(pred, confidence)
# Out:
# Battery 0.7907241
